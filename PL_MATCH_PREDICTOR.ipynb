# %%
import pandas as pd

# %%
df = pd.read_csv("matches.csv",index_col=0)

# %%
df.head()
# Out:
#          date           time            comp        round  day venue result  \
# 0  2020-09-21  20:15 (21:15)  Premier League  Matchweek 2  Mon  Away      W
# 2  2020-09-27  16:30 (17:30)  Premier League  Matchweek 3  Sun  Home      L
# 4  2020-10-03  17:30 (18:30)  Premier League  Matchweek 4  Sat  Away      D
# 5  2020-10-17  17:30 (18:30)  Premier League  Matchweek 5  Sat  Home      W
# 7  2020-10-24  12:30 (13:30)  Premier League  Matchweek 6  Sat  Away      D
#
#    gf  ga        opponent  ...  match report  notes  sh  sot  dist fk pk  \
# 0   3   1          Wolves  ...  Match Report    NaN  13    8  21.1  2  1
# 2   2   5  Leicester City  ...  Match Report    NaN  16    5  19.8  1  0
# 4   1   1    Leeds United  ...  Match Report    NaN  23    1  18.2  1  0
# 5   1   0         Arsenal  ...  Match Report    NaN  13    5  17.7  0  0
# 7   1   1        West Ham  ...  Match Report    NaN  14    7  20.9  1  0
#
#   pkatt  season             team
# 0     1    2024  Manchester City
# 2     0    2024  Manchester City
# 4     0    2024  Manchester City
# 5     0    2024  Manchester City
# 7     0    2024  Manchester City
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance      1633
# captain            0
# formation          0
# referee            0
# match report       0
# notes           4788
# sh                 0
# sot                0
# dist               2
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
df.drop(columns = ["attendance","referee","notes","match report","season"])
# Out:
#          date           time            comp         round  day venue result  \
# 0  2020-09-21  20:15 (21:15)  Premier League   Matchweek 2    0  Away      W
# 2  2020-09-27  16:30 (17:30)  Premier League   Matchweek 3    6  Home      L
# 4  2020-10-03  17:30 (18:30)  Premier League   Matchweek 4    5  Away      D
# 5  2020-10-17  17:30 (18:30)  Premier League   Matchweek 5    5  Home      W
# 7  2020-10-24  12:30 (13:30)  Premier League   Matchweek 6    5  Away      D
# ..        ...            ...             ...           ...  ...   ...    ...
# 87 2020-07-07  18:00 (19:00)  Premier League  Matchweek 34    1  Away      L
# 88 2020-07-11  12:30 (13:30)  Premier League  Matchweek 35    5  Home      L
# 89 2020-07-14  20:15 (21:15)  Premier League  Matchweek 36    1  Away      L
# 90 2020-07-18  17:30 (18:30)  Premier League  Matchweek 37    5  Home      L
# 91 2020-07-26  16:00 (17:00)  Premier League  Matchweek 38    6  Away      L
#
#     gf  ga         opponent  ...  sot  dist  fk pk pkatt             team  \
# 0    3   1           Wolves  ...    8  21.1   2  1     1  Manchester City
# 2    2   5   Leicester City  ...    5  19.8   1  0     0  Manchester City
# 4    1   1     Leeds United  ...    1  18.2   1  0     0  Manchester City
# 5    1   0          Arsenal  ...    5  17.7   0  0     0  Manchester City
# 7    1   1         West Ham  ...    7  20.9   1  0     0  Manchester City
# ..  ..  ..              ...  ...  ...   ...  .. ..   ...              ...
# 87   1   2          Watford  ...    3  16.9   1  0     0     Norwich City
# 88   0   4         West Ham  ...    2  19.8   1  0     0     Norwich City
# 89   0   1          Chelsea  ...    0  20.6   0  0     0     Norwich City
# 90   0   2          Burnley  ...    2  13.4   0  0     0     Norwich City
# 91   0   5  Manchester City  ...    4  19.8   0  0     0     Norwich City
#
#     H/A  opp_code  hours  target
# 0     0        25     20       1
# 2     1        11     16       0
# 4     0        10     17       0
# 5     1         0     17       1
# 7     0        24     12       0
# ..  ...       ...    ...     ...
# 87    0        22     18       0
# 88    1        24     12       0
# 89    0         6     20       0
# 90    1         5     17       0
# 91    0        14     16       0
#
# [4788 rows x 26 columns]

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["H/A"] = df["venue"].astype("category").cat.codes

# %%
df["opp_code"] = df["opponent"].astype("category").cat.codes

# %%
df["hours"] = df["time"].str.replace(":.+","",regex=True).astype("int")

# %%
df["day"] = df["date"].dt.dayofweek

# %%
df["target"] = (df["result"]=="W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(min_samples_split = 10,n_estimators = 300,random_state = 1)

# %%
train = df[df["date"] < '2024-01-01']

# %%
test = df[df["date"] > '2024-01-01']

# %%
predictors = ["H/A","opp_code","hours","day"]

# %%
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=300, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"],preds)

# %%
acc
# Out:
# 0.6420765027322405

# %%
combined = pd.DataFrame(dict(actual = test["target"],prediction = preds))

# %%
pd.crosstab(index=combined["actual"],columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           182  47
# 1            84  53

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"],preds)
# Out:
# 0.53

# %%
grouped_matches = df.groupby("team")
group = grouped_matches.get_group("Liverpool")

# %%
group.reset_index()
# Out:
#      index       date           time            comp         round  day venue  \
# 0        1 2020-09-12  17:30 (18:30)  Premier League   Matchweek 1    5  Home
# 1        2 2020-09-20  16:30 (17:30)  Premier League   Matchweek 2    6  Away
# 2        4 2020-09-28  20:00 (21:00)  Premier League   Matchweek 3    0  Home
# 3        6 2020-10-04  19:15 (20:15)  Premier League   Matchweek 4    6  Away
# 4        7 2020-10-17  12:30 (13:30)  Premier League   Matchweek 5    5  Away
# ..     ...        ...            ...             ...           ...  ...   ...
# 261    131 2020-07-08  20:15 (21:15)  Premier League  Matchweek 34    2  Away
# 262    132 2020-07-11  15:00 (16:00)  Premier League  Matchweek 35    5  Home
# 263    133 2020-07-15  20:15 (21:15)  Premier League  Matchweek 36    2  Away
# 264    134 2020-07-22  20:15 (21:15)  Premier League  Matchweek 37    2  Home
# 265    135 2020-07-26  16:00 (17:00)  Premier League  Matchweek 38    6  Away
#
#     result  gf  ga  ...  dist  fk  pk  pkatt  season       team H/A opp_code  \
# 0        W   4   3  ...  18.4   0   2      2    2024  Liverpool   1       10
# 1        W   2   0  ...  18.2   1   0      0    2024  Liverpool   0        6
# 2        W   3   1  ...  17.9   0   0      0    2024  Liverpool   1        0
# 3        L   2   7  ...  16.3   1   0      0    2024  Liverpool   0        1
# 4        D   2   2  ...  16.0   2   0      0    2024  Liverpool   0        8
# ..     ...  ..  ..  ...   ...  ..  ..    ...     ...        ...  ..      ...
# 261      W   3   1  ...  14.2   0   0      0    2020  Liverpool   0        4
# 262      D   1   1  ...  18.3   1   0      0    2020  Liverpool   1        5
# 263      L   1   2  ...  16.7   0   0      0    2020  Liverpool   0        0
# 264      W   5   3  ...  14.4   1   0      0    2020  Liverpool   1        6
# 265      W   3   1  ...  20.0   0   0      0    2020  Liverpool   0       16
#
#     hours  target
# 0      17       1
# 1      16       1
# 2      20       1
# 3      19       0
# 4      12       0
# ..    ...     ...
# 261    20       1
# 262    15       0
# 263    20       0
# 264    20       1
# 265    16       1
#
# [266 rows x 32 columns]

# %%
def rolling_averages(group,cols,new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5,closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf","ga","sh","sot","dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
rolling_averages(group,cols,new_cols)
# Out:
#          date           time            comp         round  day venue result  \
# 4  2019-08-24  17:30 (18:30)  Premier League   Matchweek 3    5  Home      W
# 5  2019-08-31  17:30 (18:30)  Premier League   Matchweek 4    5  Away      W
# 86 2019-08-31  17:30 (18:30)  Premier League   Matchweek 4    5  Away      W
# 6  2019-09-14  12:30 (13:30)  Premier League   Matchweek 5    5  Home      W
# 87 2019-09-14  12:30 (13:30)  Premier League   Matchweek 5    5  Home      W
# ..        ...            ...             ...           ...  ...   ...    ...
# 57 2024-04-24  20:00 (21:00)  Premier League  Matchweek 29    2  Away      L
# 58 2024-04-27  12:30 (14:30)  Premier League  Matchweek 35    5  Away      D
# 59 2024-05-05  16:30 (18:30)  Premier League  Matchweek 36    6  Home      W
# 60 2024-05-13  20:00 (22:00)  Premier League  Matchweek 37    0  Away      D
# 61 2024-05-19  16:00 (18:00)  Premier League  Matchweek 38    6  Home      W
#
#     gf  ga       opponent  ...  hours  target  gf_rolling  ga_rolling  \
# 4    3   1        Arsenal  ...     17       1         3.0         1.0
# 5    3   0        Burnley  ...     17       1         2.8         1.0
# 86   3   0        Burnley  ...     17       1         2.6         0.8
# 6    3   1  Newcastle Utd  ...     12       1         2.8         0.6
# 87   3   1  Newcastle Utd  ...     12       1         3.0         0.6
# ..  ..  ..            ...  ...    ...     ...         ...         ...
# 57   0   2        Everton  ...     20       0         2.0         1.2
# 58   2   2       West Ham  ...     12       0         1.6         1.4
# 59   4   2      Tottenham  ...     16       1         1.4         1.6
# 60   3   3    Aston Villa  ...     20       0         1.8         1.6
# 61   2   0         Wolves  ...     16       1         2.4         2.0
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4        16.8         6.0        18.04        0.8         0.2            0.2
# 5        18.6         5.4        18.38        0.6         0.4            0.4
# 86       18.6         5.4        19.16        0.4         0.4            0.4
# 6        18.6         5.6        19.64        0.2         0.4            0.4
# 87       19.8         6.0        18.64        0.0         0.4            0.4
# ..        ...         ...          ...        ...         ...            ...
# 57       24.2         7.0        16.70        0.8         0.2            0.2
# 58       22.8         6.8        16.74        0.8         0.2            0.2
# 59       22.6         6.6        16.44        0.8         0.2            0.2
# 60       22.2         7.8        16.00        0.8         0.0            0.0
# 61       20.8         8.2        16.92        0.6         0.0            0.0
#
# [261 rows x 39 columns]

# %%
df_rolling = df.groupby(df["team"]).apply(lambda x: rolling_averages(x, cols, new_cols))
df_rolling
# Out:
# C:\Users\carat\AppData\Local\Temp\ipykernel_24032\3194075726.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df.groupby(df["team"]).apply(lambda x: rolling_averages(x, cols, new_cols))
#                                  date           time            comp  \
# team
# Arsenal                 87 2019-09-22  16:30 (17:30)  Premier League
#                         89 2019-09-30  20:00 (21:00)  Premier League
#                         91 2019-10-06  14:00 (15:00)  Premier League
#                         92 2019-10-21  20:00 (21:00)  Premier League
#                         94 2019-10-27  16:30 (18:30)  Premier League
# ...                               ...            ...             ...
# Wolverhampton Wanderers 41 2024-04-24  19:45 (20:45)  Premier League
#                         42 2024-04-27  15:00 (17:00)  Premier League
#                         43 2024-05-04  17:30 (19:30)  Premier League
#                         44 2024-05-11  15:00 (17:00)  Premier League
#                         45 2024-05-19  16:00 (18:00)  Premier League
#
#                                    round  day venue result  gf  ga  \
# team
# Arsenal                 87   Matchweek 6    6  Home      W   3   2
#                         89   Matchweek 7    0  Away      D   1   1
#                         91   Matchweek 8    6  Home      W   1   0
#                         92   Matchweek 9    0  Away      L   0   1
#                         94  Matchweek 10    6  Home      D   2   2
# ...                                  ...  ...   ...    ...  ..  ..
# Wolverhampton Wanderers 41  Matchweek 29    2  Home      L   0   1
#                         42  Matchweek 35    5  Home      W   2   1
#                         43  Matchweek 36    5  Away      L   1   5
#                         44  Matchweek 37    5  Home      L   1   3
#                         45  Matchweek 38    6  Away      L   0   2
#
#                                    opponent  ...  hours  target  gf_rolling  \
# team                                         ...
# Arsenal                 87      Aston Villa  ...     16       1         1.6
#                         89   Manchester Utd  ...     20       0         2.0
#                         91      Bournemouth  ...     14       1         1.8
#                         92    Sheffield Utd  ...     20       0         1.8
#                         94   Crystal Palace  ...     16       0         1.4
# ...                                     ...  ...    ...     ...         ...
# Wolverhampton Wanderers 41      Bournemouth  ...     19       0         0.8
#                         42       Luton Town  ...     15       1         0.8
#                         43  Manchester City  ...     17       0         1.0
#                         44   Crystal Palace  ...     15       0         1.0
#                         45        Liverpool  ...     16       0         0.8
#
#                             ga_rolling sh_rolling sot_rolling dist_rolling  \
# team
# Arsenal                 87         1.6       13.0         5.2        18.10
#                         89         2.0       15.4         5.8        18.70
#                         91         2.0       14.4         5.0        18.28
#                         92         1.4       15.0         4.8        17.54
#                         94         1.2       11.6         3.8        17.68
# ...                                ...        ...         ...          ...
# Wolverhampton Wanderers 41         1.8       10.0         3.4        17.72
#                         42         1.6       10.4         3.6        18.82
#                         43         1.6       11.4         4.2        20.10
#                         44         2.2        9.2         3.2        16.82
#                         45         2.4        9.8         4.2        16.52
#
#                            fk_rolling  pk_rolling  pkatt_rolling
# team
# Arsenal                 87        0.6         0.0            0.0
#                         89        1.0         0.2            0.2
#                         91        1.2         0.2            0.2
#                         92        1.0         0.2            0.2
#                         94        0.8         0.2            0.2
# ...                               ...         ...            ...
# Wolverhampton Wanderers 41        0.4         0.2            0.2
#                         42        0.2         0.2            0.2
#                         43        0.2         0.2            0.2
#                         44        0.0         0.0            0.0
#                         45        0.0         0.0            0.0
#
# [4652 rows x 39 columns]

# %%
df_rolling.index = range(df_rolling.shape[0])

# %%
df_rolling
# Out:
#            date           time            comp         round  day venue  \
# 0    2019-09-22  16:30 (17:30)  Premier League   Matchweek 6    6  Home
# 1    2019-09-30  20:00 (21:00)  Premier League   Matchweek 7    0  Away
# 2    2019-10-06  14:00 (15:00)  Premier League   Matchweek 8    6  Home
# 3    2019-10-21  20:00 (21:00)  Premier League   Matchweek 9    0  Away
# 4    2019-10-27  16:30 (18:30)  Premier League  Matchweek 10    6  Home
# ...         ...            ...             ...           ...  ...   ...
# 4647 2024-04-24  19:45 (20:45)  Premier League  Matchweek 29    2  Home
# 4648 2024-04-27  15:00 (17:00)  Premier League  Matchweek 35    5  Home
# 4649 2024-05-04  17:30 (19:30)  Premier League  Matchweek 36    5  Away
# 4650 2024-05-11  15:00 (17:00)  Premier League  Matchweek 37    5  Home
# 4651 2024-05-19  16:00 (18:00)  Premier League  Matchweek 38    6  Away
#
#      result  gf  ga         opponent  ...  hours  target  gf_rolling  \
# 0         W   3   2      Aston Villa  ...     16       1         1.6
# 1         D   1   1   Manchester Utd  ...     20       0         2.0
# 2         W   1   0      Bournemouth  ...     14       1         1.8
# 3         L   0   1    Sheffield Utd  ...     20       0         1.8
# 4         D   2   2   Crystal Palace  ...     16       0         1.4
# ...     ...  ..  ..              ...  ...    ...     ...         ...
# 4647      L   0   1      Bournemouth  ...     19       0         0.8
# 4648      W   2   1       Luton Town  ...     15       1         0.8
# 4649      L   1   5  Manchester City  ...     17       0         1.0
# 4650      L   1   3   Crystal Palace  ...     15       0         1.0
# 4651      L   0   2        Liverpool  ...     16       0         0.8
#
#       ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# 0            1.6       13.0         5.2        18.10        0.6         0.0
# 1            2.0       15.4         5.8        18.70        1.0         0.2
# 2            2.0       14.4         5.0        18.28        1.2         0.2
# 3            1.4       15.0         4.8        17.54        1.0         0.2
# 4            1.2       11.6         3.8        17.68        0.8         0.2
# ...          ...        ...         ...          ...        ...         ...
# 4647         1.8       10.0         3.4        17.72        0.4         0.2
# 4648         1.6       10.4         3.6        18.82        0.2         0.2
# 4649         1.6       11.4         4.2        20.10        0.2         0.2
# 4650         2.2        9.2         3.2        16.82        0.0         0.0
# 4651         2.4        9.8         4.2        16.52        0.0         0.0
#
#       pkatt_rolling
# 0               0.0
# 1               0.2
# 2               0.2
# 3               0.2
# 4               0.2
# ...             ...
# 4647            0.2
# 4648            0.2
# 4649            0.2
# 4650            0.0
# 4651            0.0
#
# [4652 rows x 39 columns]

# %%
def make_predictions(data,predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors],train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"],prediction = preds, index=test.index))
    precision = precision_score(test["target"],preds)
    return combined,precision

# %%
combined,precision = make_predictions(df_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6574074074074074

# %%
combined
# Out:
#       actual  prediction  index
# 205        1           1    205
# 206        1           0    206
# 207        1           0    207
# 208        1           1    208
# 209        1           1    209
# ...      ...         ...    ...
# 4647       0           0   4647
# 4648       1           0   4648
# 4649       0           0   4649
# 4650       0           0   4650
# 4651       0           0   4651
#
# [366 rows x 3 columns]

# %%
combined = combined.merge(df_rolling[["date","team","opponent","result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  prediction  index       date                     team  \
# 205        1           1    205 2024-01-20                  Arsenal
# 206        1           0    206 2024-01-30                  Arsenal
# 207        1           0    207 2024-02-04                  Arsenal
# 208        1           1    208 2024-02-11                  Arsenal
# 209        1           1    209 2024-02-17                  Arsenal
# ...      ...         ...    ...        ...                      ...
# 4647       0           0   4647 2024-04-24  Wolverhampton Wanderers
# 4648       1           0   4648 2024-04-27  Wolverhampton Wanderers
# 4649       0           0   4649 2024-05-04  Wolverhampton Wanderers
# 4650       0           0   4650 2024-05-11  Wolverhampton Wanderers
# 4651       0           0   4651 2024-05-19  Wolverhampton Wanderers
#
#              opponent result
# 205    Crystal Palace      W
# 206   Nott'ham Forest      W
# 207         Liverpool      W
# 208          West Ham      W
# 209           Burnley      W
# ...               ...    ...
# 4647      Bournemouth      L
# 4648       Luton Town      W
# 4649  Manchester City      L
# 4650   Crystal Palace      L
# 4651        Liverpool      L
#
# [366 rows x 7 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key:key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Tottenham Hotspur": "Tottenham", 
    "West Ham United": "West Ham", 
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping['Brighton and Hove Albion']
# Out:
# 'Brighton'

# %%
combined["new team"] = combined["team"].map(mapping)

# %%
combined.drop(columns = "index")
# Out:
#       actual  prediction       date                     team         opponent  \
# 205        1           1 2024-01-20                  Arsenal   Crystal Palace
# 206        1           0 2024-01-30                  Arsenal  Nott'ham Forest
# 207        1           0 2024-02-04                  Arsenal        Liverpool
# 208        1           1 2024-02-11                  Arsenal         West Ham
# 209        1           1 2024-02-17                  Arsenal          Burnley
# ...      ...         ...        ...                      ...              ...
# 4647       0           0 2024-04-24  Wolverhampton Wanderers      Bournemouth
# 4648       1           0 2024-04-27  Wolverhampton Wanderers       Luton Town
# 4649       0           0 2024-05-04  Wolverhampton Wanderers  Manchester City
# 4650       0           0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 4651       0           0 2024-05-19  Wolverhampton Wanderers        Liverpool
#
#      result new team
# 205       W  Arsenal
# 206       W  Arsenal
# 207       W  Arsenal
# 208       W  Arsenal
# 209       W  Arsenal
# ...     ...      ...
# 4647      L   Wolves
# 4648      W   Wolves
# 4649      L   Wolves
# 4650      L   Wolves
# 4651      L   Wolves
#
# [366 rows x 7 columns]

# %%
merged = combined.merge(combined,left_on = ["date","new team"], right_on = ["date","opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x  index_x       date                   team_x  \
# 0           1             1      205 2024-01-20                  Arsenal
# 1           1             0      206 2024-01-30                  Arsenal
# 2           1             0      207 2024-02-04                  Arsenal
# 3           1             1      208 2024-02-11                  Arsenal
# 4           1             1      209 2024-02-17                  Arsenal
# ..        ...           ...      ...        ...                      ...
# 307         0             0     4647 2024-04-24  Wolverhampton Wanderers
# 308         1             0     4648 2024-04-27  Wolverhampton Wanderers
# 309         0             0     4649 2024-05-04  Wolverhampton Wanderers
# 310         0             0     4650 2024-05-11  Wolverhampton Wanderers
# 311         0             0     4651 2024-05-19  Wolverhampton Wanderers
#
#           opponent_x result_x new team_x  actual_y  prediction_y  index_y  \
# 0     Crystal Palace        W    Arsenal         0             0     1532
# 1    Nott'ham Forest        W    Arsenal         0             0     3454
# 2          Liverpool        W    Arsenal         0             1     2535
# 3           West Ham        W    Arsenal         0             0     4414
# 4            Burnley        W    Arsenal         0             0     1058
# ..               ...      ...        ...       ...           ...      ...
# 307      Bournemouth        L     Wolves         1             0      550
# 308       Luton Town        W     Wolves         0             0     2580
# 309  Manchester City        L     Wolves         1             1     2841
# 310   Crystal Palace        L     Wolves         1             1     1548
# 311        Liverpool        L     Wolves         1             1     2550
#
#                 team_y opponent_y result_y         new team_y
# 0       Crystal Palace    Arsenal        L     Crystal Palace
# 1    Nottingham Forest    Arsenal        L  Nottingham Forest
# 2            Liverpool    Arsenal        L          Liverpool
# 3      West Ham United    Arsenal        L           West Ham
# 4              Burnley    Arsenal        L            Burnley
# ..                 ...        ...      ...                ...
# 307        Bournemouth     Wolves        W        Bournemouth
# 308         Luton Town     Wolves        L         Luton Town
# 309    Manchester City     Wolves        W    Manchester City
# 310     Crystal Palace     Wolves        W     Crystal Palace
# 311          Liverpool     Wolves        W          Liverpool
#
# [312 rows x 15 columns]
